# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_csv('rian_activity.csv')
df.head(5)
# Out:
#      Date  Active energy burned(Cal)  Apple Watch stand hours(hr)  \
# 0  1/4/22                    213.669                            5
# 1  1/5/22                    462.683                           12
# 2  1/6/22                    270.017                            7
# 3  1/8/22                    371.465                           10
# 4  1/9/22                    446.727                           12
#
#    Basal energy burned(Cal)  Distance walking or running  \
# 0                  2103.876                        1.408
# 1                  2314.592                        1.430
# 2                  2170.818                        1.955
# 3                  2241.646                        1.725
# 4                  2242.032                        1.970
#
#    Heart rate(count/min)  Resting heart rate(count/min)  Stand time(min)  \
# 0                 84.013                           70.0               43
# 1                 79.085                           66.0               68
# ...

# %%
df.dtypes
# Out:
# Date                              object
# Active energy burned(Cal)        float64
# Apple Watch stand hours(hr)        int64
# Basal energy burned(Cal)         float64
# Distance walking or running      float64
# Heart rate(count/min)            float64
# Resting heart rate(count/min)    float64
# Stand time(min)                    int64
# Step count                       float64
# Walk Heart Avg                   float64
# dtype: object

# %%
df.describe()
# Out:
#        Active energy burned(Cal)  Apple Watch stand hours(hr)  \
# count                 107.000000                   107.000000
# mean                  428.829150                    10.719626
# std                   130.820238                     2.847688
# min                   121.493000                     3.000000
# 25%                   366.391000                     9.000000
# 50%                   430.965000                    11.000000
# 75%                   499.494500                    13.000000
# max                   787.629000                    18.000000
#
#        Basal energy burned(Cal)  Distance walking or running  \
# count                107.000000                   107.000000
# mean                2178.593748                     2.136056
# std                  211.552908                     0.795320
# min                  892.645000                     0.671000
# 25%                 2159.457500                     1.634500
# ...

# %%
df[['Step count', 'Distance walking or running']]
# Out:
#      Step count  Distance walking or running
# 0      3183.244                        1.408
# 1      3141.388                        1.430
# 2      4575.000                        1.955
# 3      3767.700                        1.725
# 4      4303.000                        1.970
# ..          ...                          ...
# 102    2817.000                        1.235
# 103    5837.000                        2.757
# 104    5830.209                        2.763
# 105    2799.492                        1.312
# 106    5146.771                        2.385
#
# [107 rows x 2 columns]

# %%
df[df['Distance walking or running'] > 4]
# Out:
#        Date  Active energy burned(Cal)  Apple Watch stand hours(hr)  \
# 43   3/5/22                    425.654                           10
# 81  7/16/22                    740.924                           13
# 92  8/22/22                    774.766                           13
# 94  8/24/22                    787.629                           18
#
#     Basal energy burned(Cal)  Distance walking or running  \
# 43                  2112.933                        4.046
# 81                  2380.782                        4.845
# 92                  2310.383                        4.841
# 94                  2345.721                        5.253
#
#     Heart rate(count/min)  Resting heart rate(count/min)  Stand time(min)  \
# 43                 86.976                           76.0              100
# 81                 88.506                           74.0              267
# 92                 75.683                           56.0              220
# ...

# %%
df[(df['Distance walking or running'] > 3) & (df['Distance walking or running'] < 5)]
# Out:
#        Date  Active energy burned(Cal)  Apple Watch stand hours(hr)  \
# 11  1/18/22                    694.650                           14
# 43   3/5/22                    425.654                           10
# 57  3/30/22                    684.476                           15
# 60   4/2/22                    546.527                           10
# 74   7/8/22                    230.171                            6
# 75   7/9/22                    301.204                            8
# 81  7/16/22                    740.924                           13
# 92  8/22/22                    774.766                           13
#
#     Basal energy burned(Cal)  Distance walking or running  \
# 11                  2316.934                        3.798
# 43                  2112.933                        4.046
# 57                  2448.128                        3.103
# 60                  2220.443                        3.294
# 74                   892.645                        3.085
# ...
